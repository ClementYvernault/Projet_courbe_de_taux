# %%
# %pwd
# Out:
# 'c:\\Users\\yvern\\Documents\\Cours 2025-2026\\courbe de taux\\Projet_courbe_de_taux\\code'

# %%
# Librairies
import pandas as pd

# %% [markdown]
# # Partie I.1

# %%
file_path = '../data/Mkt Data.xlsx'

df = pd.read_excel(file_path, sheet_name=0)

df.head(20)
df = df[['Unnamed: 0', 'MAT', 'MKT']].copy()
df.columns = ['Instrument', 'Maturity', 'MarketRate']
df_clean = df.copy()
display(df_clean)
# Out:
#    Instrument  Maturity  MarketRate
# 0          MM      0.25    0.030698
# 1          MM      0.50    0.026192
# 2          MM      0.75    0.023958
# 3          MM      1.00    0.022980
# 4         FUT      1.25    0.978692
# 5         FUT      1.50    0.977095
# 6         FUT      1.75    0.974982
# 7         FUT      2.00    0.972912
# 8         FUT      2.25    0.970984
# 9         FUT      2.50    0.969711
# 10        FUT      2.75    0.968436
# 11       SWAP      3.00    0.026112
# 12       SWAP      4.00    0.028118
# 13       SWAP      5.00    0.029681
# 14       SWAP      6.00    0.031107
# 15       SWAP      7.00    0.032313
# 16       SWAP      8.00    0.033382
# 17       SWAP      9.00    0.034385
# 18       SWAP     10.00    0.035313
# 19       SWAP     11.00    0.036197
# 20       SWAP     12.00    0.037004
# 21       SWAP     13.00    0.037668
# 22       SWAP     14.00    0.038202
# 23       SWAP     15.00    0.038625
# 24       SWAP     16.00    0.038953
# ...

# %% [markdown]
# ### I.1.1 Type de courbe
#
# Il s'agit d'une courbe de taux interbancaire.

# %% [markdown]
# ### I.1.2

# %% [markdown]
# **Justification :**
#
# Cette courbe est segmentée et construite à partir de trois types d'instruments de gré à gré ou listés, typiques des échanges entre banques :
#
# - Instruments du marché monétaire (MM) pour les maturités courtes jusqu'à 1 an.
#
# - Contrats futures sur taux d’intérêt (FUT) pour les maturités moyennes jusqu'à 2,75 ans.
#
# - Swaps de taux d'intérêt (SWAP) pour les maturités longues jusqu'à 30 ans.
